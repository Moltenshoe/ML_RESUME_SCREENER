# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../datasets/Resume.csv", index_col="ID")
df
# Out:
#                                                  Resume_str  \
# ID
# 16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 33176873           HR DIRECTOR       Summary      Over 2...
# 27018550           HR SPECIALIST       Summary    Dedica...
# 17812897           HR MANAGER         Skill Highlights  ...
# ...                                                     ...
# 99416532           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...
# 24589765           GOVERNMENT RELATIONS, COMMUNICATIONS ...
# 31605080           GEEK SQUAD AGENT         Professional...
# 21190805           PROGRAM DIRECTOR / OFFICE MANAGER    ...
# 37473139           STOREKEEPER II       Professional Sum...
#
#                                                 Resume_html  Category
# ID
# 16852973  <div class="fontsize fontface vmargins hmargin...        HR
# 22323967  <div class="fontsize fontface vmargins hmargin...        HR
# ...

# %%
df.isna().any()
# Out:
# Resume_str    False
# Category      False
# dtype: bool

# %%
df.drop(columns=["Resume_html"], inplace=True)

# %%
df["Category"].value_counts()
# Out:
# Category
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# ADVOCATE                  118
# CHEF                      118
# FINANCE                   118
# ENGINEERING               118
# ACCOUNTANT                118
# FITNESS                   117
# AVIATION                  117
# SALES                     116
# HEALTHCARE                115
# CONSULTANT                115
# BANKING                   115
# CONSTRUCTION              112
# PUBLIC-RELATIONS          111
# HR                        110
# DESIGNER                  107
# ARTS                      103
# TEACHER                   102
# APPAREL                    97
# DIGITAL-MEDIA              96
# AGRICULTURE                63
# AUTOMOBILE                 36
# BPO                        22
# Name: count, dtype: int64
